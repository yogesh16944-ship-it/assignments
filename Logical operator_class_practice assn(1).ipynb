# %% [markdown]
# ## Problem 1: Check sign
#
# **Question:** Write a program that checks if a number is positive, negative, or zero.
#
# **Approach:** Think about comparing the number with 0 using if, elif, and else.

# %%
# Enter your answer here
number=int(input("enter a num: "))

if number>0:
    print("positive")
elif number <0:
   print("Negative hai")
else:
  print("Number is 0")
# Out:
# enter a num: 0
# Number is 0

# %% [markdown]
# ## Problem 2: Leap Year
#
# **Question:** Check if a given year is a leap year.
#
# **Approach:** Apply the rules: divisible by 4, but centuries must be divisible by 400.
#
# Rules: Year divisible by 4 is leap, but if divisible by 100 it must also be divisible by 400.

# %%
# Enter your answer here
year= int(input("enter a year: "))
if year%4==0 or year%100!=0 and year%400==0:
  print("leap year")
else:
  print("not a leap year")

# %% [markdown]
# ## Problem 3: Grade Bands
#
# **Question:** Print grade category based on marks: Excellent, Good, Average, Fail.
#
# **Approach:** Build multiple conditions using elif to check ranges.
#
# Take marks (0-100) and print:
# - 90–100 → Excellent
# - 75–89 → Good
# - 50–74 → Average
# - else → Fail

# %%
# Enter your answer here
marks=int(input("enter your marks :"))
if marks >=90 and marks<=100:
  print("Excellent")
elif marks >=75 and marks<=89:
  print("good")
elif marks >=50 and marks<=74:
  print("average")
else :
  print("fail")

# %% [markdown]
# ## Problem 4: Validate Login
#
# **Question:** Check username=='admin' and password=='1234'.
#
# **Approach:** Use logical AND to validate both conditions.
#
#
# Input: username & password.
#
# If username == 'admin' and password == '1234'
# print 'Login successful',
# else 'Invalid credentials'.

# %%
# Enter your answer here
user_name=str(input("enter your user name: "))
password=str(input("enter password: "))

if user_name=='admin' and password=='1234':
  print("login successful")
else:
  print("invalid credentials")

# %% [markdown]
# ## Problem 5: Movie Ticket Discount
#
# **Question:** Apply discount based on age.
#
# **Approach:** Use ordered elif statements from smallest to largest age group.
#
# Apply discounts based on age:
# - Age < 12 → 50% discount
# - Age between 12 and 18 → 30% discount
# - Age between 18 and 60 → no discount
# - Age > 60 → 40% discount

# %%
# Enter your answer here
age= int(input("give me your age for giving you discount"))
if age<12:
  print("hey you are alligible for 50% discount")
elif age >=12 and age<=18:
  print("you get 30%discount from our side")
elif age >=18 and age <=60:
  print("oops you got no discount")
else:
 print("hii sir you got 40% discount")

# %% [markdown]
# ## Problem 6: Placement Eligibility
#
# **Question:** Check CGPA, backlog status, and project count.
#
# **Approach:** All conditions must be true → use AND operator.
#
#
# Conditions:
# - CGPA ≥ 7
# - No backlog (enter 'yes' or 'no')
# - Completed >= 2 major projects
# Print whether the student is eligible.

# %%
# Enter your answer here
cgpa = float(input("what's your cgpa in  collage:  "))
backlog= str(input("is there any backlogs in semesters:  "))
projects = int(input("howmany project you have ever made:  "))
if cgpa >=7 and backlog != 'yes' and projects>=2:
  print("you are elligible for placemnet")
else:
  print("sorry to say you are not elligible for our placemnent")

# %% [markdown]
# ## Problem 7: Delivery Charge System
#
# **Question:** Calculate final delivery charge based on prime membership, amount, and distance.
#
# **Approach:** Start with prime-check, then inside it apply nested if blocks.
#
# Inputs:
# - order_amount (int)
# - is_prime_member (yes/no)
# - distance_km (float)
#
# Rules:
# - If prime member → Free delivery
# - Else:
#   - If amount ≥ 500:
#     - If distance ≤ 5 km → Free
#     - Else → ₹20 extra
#   - Else:
#     - If distance ≤ 5 km → ₹30
#     - Else → ₹50

# %%
# Enter your answer here
order_amount= int(input("enter here total order amount"))
prime_member=str(input('is he prime member'))
distance = float(input("where it locates in km"))

if prime_member=='yes':
  print("he deserves free delivery")
else:
  if order_amount >=500:
    if distance <=5:
      print("free delivery")
    else:
        print("you have to pay 20 rupees extra")
  else:
    if distance <=5:
      print("need 30rupees  extra")
    else:
      print("need  50 rupees extra")

# %% [markdown]
# ## Problem 8: ATM Withdrawal Simulation
#
# **Question:** Simulate ATM rules: multiples of 100, sufficient balance, manager approval.
#
# **Approach:** Check errors first, then nested conditions for amount > 10000.
#
# Inputs:
# - balance
# - amount
#
# Logic:
# - If amount % 100 != 0 → reject (ATM works with ₹100 multiples)
# - If amount > balance → reject
# - Else:
#   - if amount > 10000 → ask for manager approval
#   - else → withdraw success

# %%
# Enter your answer here
balance=int(input("whats you total balance in account "))
amount=int(input("enter amount you want to withdrawl "))
if amount%100!=0:
  print("rejected(atm will works with 100 multiples)")
if amount > balance:
  print("rejected(insufficiant balance)")
else:
  if amount>10000:
    print("manager will approve your payment")
  else:
      print("successfully withdrawl")

# %% [markdown]
# ## Problem 9: Employee Performance Rating
#
# **Question:** Assign performance rating based on sales, feedback, attendance.
#
# **Approach:** Prioritize attendance rule, then apply nested conditions.
#
# Inputs:
# - sales (₹)
# - feedback (0-5 scale)
# - attendance (%)
#
# Logic:
# - If attendance < 70 → 'Poor'
# - Else:
#   - If sales > 100000 AND feedback > 4.5 → 'Excellent'
#   - If sales > 70000 OR feedback > 4 → 'Good'
#   - Else → 'Average'

# %%
# Enter your answer here
sales = int(input("what sales you done"))
feedback = int(input("what feedback you got"))
attendace=int(input("what attandense you reach"))
if attendace <70:
  print("'poor'")
else:
  if sales >100000 and feedback>4.5:
    print("'excellent'")
  elif sales>70000 or feedback>4:
    print("good")
  else:
      print("average")

# %% [markdown]
# ## Problem 10: Credit Card Eligibility
#
# **Question:** Determine card eligibility based on age, salary, credit score.
#
# **Approach:** First filter by age, then use nested if blocks for salary and credit score.
#
# Inputs:
# - salary
# - credit_score
# - age
#
# Logic:
# - If age < 21 → Not eligible
# - Else:
#   - If salary ≥ 40,000:
#     - If credit_score ≥ 750 → Gold Card
#     - Else → Silver Card
#   - Else:
#     - If credit_score ≥ 800 → Silver Card
#     - Else → Not eligible

# %%
# Enter your answer here
salary =int(input("what is your sallary"))
credit_score=int(input("what isn your credit score"))
age=int(input("what is your age"))

if age<=21:
  print("not elligible")
else:
  if salary >= 40000:
    if credit_score >=750:
      print("gold card")
    else:
      print("silver card")
  else:
    if credit_score >=800:
       print("silver card")
    else:
      print("not elligible")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Enter your answer here
# ----> 2 salary =int("what is your sallary")
#       3 credit_score=int("what isn your credit score")
#       4 age=int("what is your age")
#
# ValueError: invalid literal for int() with base 10: 'what is your sallary'
